# %% [markdown]
# # UNSW-NB15 dataset
#
# ## Analyzing dataset

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
unsw1 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15_1.csv', header=None)
unsw2 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15_2.csv', header=None)
unsw3 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15_3.csv', header=None)
unsw4 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15_4.csv', header=None)
# Out:
# C:\Users\UX430\AppData\Local\Temp/ipykernel_9048/2123842543.py:1: DtypeWarning: Columns (1,3,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   unsw1 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15_1.csv', header=None)
# C:\Users\UX430\AppData\Local\Temp/ipykernel_9048/2123842543.py:2: DtypeWarning: Columns (3,39,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   unsw2 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15_2.csv', header=None)

# %%
# Need to add the column names to the dataframes. First, let's join all the dataframes into one
unsw = pd.concat([unsw1, unsw2, unsw3, unsw4], ignore_index=True)
cols = ['srcip', 'sport', 'dstip', 'dsport', 'proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'Sload', 'Dload', 'Spkts', 'Dpkts', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz']
cols += ['trans_depth', 'res_bdy_len', 'Sjit', 'Djit', 'Stime', 'Ltime', 'Sintpkt', 'Dintpkt', 'tcprtt', 'synack', 'ackdat', 'is_sm_ips_ports', 'ct_state_ttl', 'ct_flw_http_mthd', 'is_ftp_login', 'ct_ftp_cmd', 'ct_srv_src', 'ct_srv_dst', 'ct_dst_ltm', 'ct_src_ ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label']
unsw.columns = cols

# %%
unsw
# Out:
#                 srcip  sport           dstip dsport proto state       dur  \
# 0          59.166.0.0   1390   149.171.126.6     53   udp   CON  0.001055
# 1          59.166.0.0  33661   149.171.126.9   1024   udp   CON  0.036133
# 2          59.166.0.6   1464   149.171.126.7     53   udp   CON  0.001119
# 3          59.166.0.5   3593   149.171.126.5     53   udp   CON  0.001209
# 4          59.166.0.3  49664   149.171.126.0     53   udp   CON  0.001169
# ...               ...    ...             ...    ...   ...   ...       ...
# 2540042    59.166.0.5  33094   149.171.126.7  43433   tcp   FIN  0.087306
# 2540043    59.166.0.7  20848   149.171.126.4     21   tcp   CON  0.365058
# 2540044    59.166.0.3  21511   149.171.126.9     21   tcp   CON  6.335154
# 2540045    59.166.0.9  35433   149.171.126.0     80   tcp   CON  2.200934
# 2540046  175.45.176.0  17293  149.171.126.17    110   tcp   CON  0.942984
#
#          sbytes  dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# ...

# %% [markdown]
# From now on, we will work with the 14 features that were chosen in the previous project:

# %%
#cols2 = ['proto', 'saddr', 'sport', 'daddr', 'dport', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'state', 'Stime', 'Ltime', 'Dur', 'Attack']

# %%
# Keep only the cols2 from unsw
#unsw = unsw[cols2]

# %% [markdown]
# We want to check how many rows from each 'Attack' class have null values:

# %%
# Null values in general
unsw.isnull().sum()
# Out:
# srcip                     0
# sport                     0
# dstip                     0
# dsport                    0
# proto                     0
# state                     0
# dur                       0
# sbytes                    0
# dbytes                    0
# sttl                      0
# dttl                      0
# sloss                     0
# dloss                     0
# service                   0
# Sload                     0
# Dload                     0
# Spkts                     0
# Dpkts                     0
# swin                      0
# dwin                      0
# stcpb                     0
# dtcpb                     0
# smeansz                   0
# dmeansz                   0
# trans_depth               0
# res_bdy_len               0
# Sjit                      0
# Djit                      0
# Stime                     0
# Ltime                     0
# Sintpkt                   0
# Dintpkt                   0
# tcprtt                    0
# ...

# %%
# Range of values for each column
for col in unsw.columns:
    print(col, unsw[col].unique())
# Out:
# srcip ['59.166.0.0' '59.166.0.6' '59.166.0.5' '59.166.0.3' '10.40.182.3'
#  '59.166.0.7' '10.40.170.2' '59.166.0.1' '59.166.0.2' '59.166.0.4'
#  '175.45.176.3' '175.45.176.2' '175.45.176.0' '59.166.0.8' '59.166.0.9'
#  '175.45.176.1' '10.40.182.1' '10.40.85.1' '192.168.241.243' '10.40.85.30'
#  '149.171.126.16' '149.171.126.2' '149.171.126.11' '149.171.126.4'
#  '149.171.126.5' '149.171.126.17' '149.171.126.19' '149.171.126.9'
#  '149.171.126.8' '149.171.126.7' '149.171.126.15' '149.171.126.6'
#  '149.171.126.0' '149.171.126.1' '149.171.126.3' '149.171.126.13'
#  '149.171.126.12' '149.171.126.10' '149.171.126.18' '127.0.0.1'
#  '149.171.126.14' '10.40.85.10' '10.40.182.6']
# sport [1390 33661 1464 ... 533 933 706]
# dstip ['149.171.126.6' '149.171.126.9' '149.171.126.7' '149.171.126.5'
#  '149.171.126.0' '149.171.126.4' '10.40.182.3' '10.40.170.2'
#  '149.171.126.18' '149.171.126.16' '149.171.126.8' '149.171.126.2'
#  '149.171.126.1' '149.171.126.10' '149.171.126.3' '149.171.126.15'
# ...

# %% [markdown]
# Columns 'ct_flw_http_mthd', 'is_ftp_login' and 'attack_cat' contain null values:

# %%
# Print value count in the 'Label' column  of samples with null values in columns 'ct_flw_http_mthd'and 'is_ftp_login'
print(unsw[(unsw['ct_flw_http_mthd'].isnull()) & (unsw['is_ftp_login'].isnull())]['Label'].value_counts())
# Out:
# Label
# 0    1044126
# 1     281054
# Name: count, dtype: int64

# %%
# Count of all samples with null values in the 'attack_cat' column
print(unsw[unsw['attack_cat'].isnull()]['Label'].value_counts())
# Out:
# Label
# 0    2218764
# Name: count, dtype: int64
