# %% [markdown]
# ## **Federated Learning for attack classification: 7 nodes sharing weights**
#
# IDs from this file = **id5xy** (x = 0 if experiment with dataset, x = 1 if epochs & iterations, y being integer equal or greater than 0)
#
# In this file, experiments with different datasets, and number of epochs & iterations are done. The experiments are divided into sections, based on the elements being changed.

# %% [markdown]
# ### Static elements for all experiments (execute first)

# %%
# Imports
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from tensorflow.keras import datasets, layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, BatchNormalization
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# Disable warns
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Preprocessing for test and training datasets (to be able to train and make predictions to evaluate)
def preprocessing(data): 

    # Select the 'proto' and 'state' values that I want
    data = data.loc[(data['proto'] == 'tcp') | (data['proto'] =='udp') | (data['proto'] =='icmp') | (data['proto'] =='arp') | (data['proto'] =='ipv6-icmp') | (data['proto'] =='igmp') | (data['proto'] =='rarp'), :]
    data = data.loc[(data['state'] == 'RST') | (data['state'] =='REQ') | (data['state'] =='INT') | (data['state'] =='FIN') | (data['state'] =='CON') | (data['state'] =='ECO') | (data['state'] =='ACC') | (data['state'] == 'PAR'), :]

    # Creating categories dataframe
    data_labels = pd.DataFrame()

    # Drop the invalid features and select interested data features
    data_features=data[['proto','srcip','sport','dstip','dsport','spkts','dpkts','sbytes','dbytes','state','stime','ltime','dur']]

    """PREPROCESSING"""


    # Preprocess IP and ports features
    # IP Source Address
    data_features['srcip'] = data_features['srcip'].apply(lambda x: x.split(".")[-1])
    data_features['srcip'] = data_features['srcip'].apply(lambda x: x.split(":")[-1])
    data_features['srcip'] = data_features['srcip'].apply(lambda x: int(x, 16))


    # IP Destination Address
    data_features['dstip'] = data_features['dstip'].apply(lambda x: x.split(".")[-1])
    data_features['dstip'] = data_features['dstip'].apply(lambda x: x.split(":")[-1])
    data_features['dstip'] = data_features['dstip'].apply(lambda x: int(x, 16))

    # Ports
    data_features['sport'] = data_features['sport'].apply(lambda x: x.replace('0x','') if "0x" in str(x) else x)
    data_features['dsport'] = data_features['dsport'].apply(lambda x: x.replace('0x','') if "0x" in str(x) else x)

    # Convert all ports with 0 decimal, and HEX to DEC
    data_features['sport'] = data_features['sport'].apply(lambda x: str(x)[:-2] if str(x)[-2:] == '.0' else str(x))
    data_features['sport'] = data_features['sport'].apply(lambda x: -1 if str(x).isalpha()==True else int(x,16))

    data_features['dsport'] = data_features['dsport'].apply(lambda x: str(x)[:-2] if str(x)[-2:] == '.0' else str(x))
    data_features['dsport'] = data_features['dsport'].apply(lambda x: -1 if str(x).isalpha()==True else int(x,16))

    # Convert field to int format
    data_features['srcip'] = data_features['srcip'].astype(int)
    data_features['sport'] = data_features['sport'].astype(int)
    data_features['dstip'] = data_features['dstip'].astype(int)
    data_features['dsport'] = data_features['dsport'].astype(int)

    # Convert some fields to logarithmic
    log1p_col = ['dur', 'sbytes', 'dbytes', 'spkts']

    for col in log1p_col:
        data_features[col] = data_features[col].apply(np.log1p)
        
    # Transform to One Hot Encoding the Categories - normal, dos, reconnaissance, generic, exploits, worms, fuzzers, analysis, backdoor, shellcode
    data_labels.insert(0, 'normal', data['attack_cat'].replace('normal', 1).replace(['dos', 'reconnaissance', 'generic', 'exploits', 'worms', 'fuzzers', 'analysis', 'backdoor', 'shellcode'], 0))
    data_labels.insert(1, 'dos', data['attack_cat'].replace('dos', 1).replace(['normal', 'reconnaissance', 'generic', 'exploits', 'worms', 'fuzzers', 'analysis', 'backdoor', 'shellcode'], 0))
    data_labels.insert(2, 'reconnaissance', data['attack_cat'].replace('reconnaissance', 1).replace(['normal', 'dos', 'generic', 'exploits', 'worms', 'fuzzers', 'analysis', 'backdoor', 'shellcode'], 0))
    data_labels.insert(3, 'generic', data['attack_cat'].replace('generic', 1).replace(['normal', 'dos', 'reconnaissance', 'exploits', 'worms', 'fuzzers', 'analysis', 'backdoor', 'shellcode'], 0))
    data_labels.insert(4, 'exploits', data['attack_cat'].replace('exploits', 1).replace(['normal', 'dos', 'reconnaissance', 'generic', 'worms', 'fuzzers', 'analysis', 'backdoor', 'shellcode'], 0))
    data_labels.insert(5, 'worms', data['attack_cat'].replace('worms', 1).replace(['normal', 'dos', 'reconnaissance', 'generic', 'exploits', 'fuzzers', 'analysis', 'backdoor', 'shellcode'], 0))
    data_labels.insert(6, 'fuzzers', data['attack_cat'].replace('fuzzers', 1).replace(['normal', 'dos', 'reconnaissance', 'generic', 'exploits', 'worms', 'analysis', 'backdoor', 'shellcode'], 0))
    data_labels.insert(7, 'analysis', data['attack_cat'].replace('analysis', 1).replace(['normal', 'dos', 'reconnaissance', 'generic', 'exploits', 'worms', 'fuzzers', 'backdoor', 'shellcode'], 0))
    data_labels.insert(8, 'backdoor', data['attack_cat'].replace('backdoor', 1).replace(['normal', 'dos', 'reconnaissance', 'generic', 'exploits', 'worms', 'fuzzers', 'analysis', 'shellcode'], 0))
    data_labels.insert(9, 'shellcode', data['attack_cat'].replace('shellcode', 1).replace(['normal', 'dos', 'reconnaissance', 'generic', 'exploits', 'worms', 'fuzzers', 'analysis', 'backdoor'], 0))

    data_labels = pd.get_dummies(data_labels)

    # Transform to One hot encoding - FEATURES
    data_features=pd.get_dummies(data_features)

    # Generate 2 new columns to fit with training
    auxCol=data_features['sbytes']
    auxCol=0

      # As we are using different datasets that might not have all representations, we are going to detect and add the missing columns 
    # The columns that can have types are: proto and state: need to check if all representations are done 
    state_cols = [col for col in data_features if col.startswith('state_')]
    proto_cols = [col for col in data_features if col.startswith('proto_')]
    
    # Check if all columns are present
    if 'state_PAR' not in state_cols:
        data_features.insert(data_features.shape[1], 'state_PAR', auxCol, True)
    if 'state_ACC' not in state_cols: 
        data_features.insert(data_features.shape[1], 'state_ACC', auxCol, True)
    if 'state_ECO' not in state_cols:
        data_features.insert(data_features.shape[1], 'state_ECO', auxCol, True)
    if 'state_CON' not in state_cols:
        data_features.insert(data_features.shape[1], 'state_CON', auxCol, True)
    if 'state_FIN' not in state_cols:
        data_features.insert(data_features.shape[1], 'state_FIN', auxCol, True)
    if 'state_INT' not in state_cols:
        data_features.insert(data_features.shape[1], 'state_INT', auxCol, True)
    if 'state_REQ' not in state_cols:
        data_features.insert(data_features.shape[1], 'state_REQ', auxCol, True)
    if 'state_RST' not in state_cols:
        data_features.insert(data_features.shape[1], 'state_RST', auxCol, True)
    if 'proto_igmp' not in proto_cols:
        data_features.insert(data_features.shape[1], 'proto_igmp', auxCol, True)
    if 'proto_arp' not in proto_cols:
        data_features.insert(data_features.shape[1], 'proto_arp', auxCol, True)
    if 'proto_icmp' not in proto_cols:
        data_features.insert(data_features.shape[1], 'proto_icmp', auxCol, True)
    if 'proto_udp' not in proto_cols:
        data_features.insert(data_features.shape[1], 'proto_udp', auxCol, True)
    if 'proto_tcp' not in proto_cols:
        data_features.insert(data_features.shape[1], 'proto_tcp', auxCol, True)

    # Normalize all data features
    data_features = StandardScaler().fit_transform(data_features)

    #Add dimension to data features
    data_features = np.expand_dims(data_features, axis=2)
    data_features = np.expand_dims(data_features, axis=3)

    x = data_features
    y = data_labels.to_numpy()

    return x, y

# %%
# Model building and definition
def build_model(input_shape):
    model = models.Sequential()
    model.add(layers.Conv2D(filters=32,  input_shape=input_shape, kernel_size=(1,10), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D(pool_size=(1, 1), padding='same'))
    model.add(layers.Conv2D(filters=64,  input_shape=input_shape, kernel_size=(1,10), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D(pool_size=(1, 1), padding='same'))
    model.add(layers.Flatten())
    model.add(Dense(444, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    return model

# %%
# Returns values of loss, accuracy, f1, precision and recall of model evaluating with test dataset 
def evaluation(model, x, y): 
    loss, accuracy = model.evaluate(x, y)
    y_pred = model.predict(x)
    y_pred = np.argmax(y_pred, axis=1)
    y = np.argmax(y, axis=1)
    report = classification_report(y, y_pred, labels = [i for i in range(10)], target_names=['normal', 'dos', 'reconnaissance', 'generic', 'exploits', 'worms', 'fuzzers', 'analysis', 'backdoor', 'shellcode'], output_dict=True)
    # Obtain f1, precision and recall from the report
    f1 = report['weighted avg']['f1-score']
    precision = report['weighted avg']['precision']
    recall = report['weighted avg']['recall']
    return loss, accuracy, f1, precision, recall

# %% [markdown]
# ### Experiments with datasets

# %% [markdown]
# #### Dataset 7A

# %%
# Load training datasets and testing datasets 
training1 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part1.csv')
training2 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part2.csv')
training3 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part3.csv')
training4 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part4.csv')
training5 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part5.csv')
training6 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part6.csv')
training7 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part7.csv')
test_basic = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test-Basic.csv')
test_plus = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test+.csv')
# Out:
# C:\Users\UX430\AppData\Local\Temp/ipykernel_15040/1809786618.py:9: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_basic = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test-Basic.csv')

# %%
# Define 
node_datasets = [training1, training2, training3, training4, training5, training6, training7]
num_nodes = 7
global_updates = 10

# Define model training parameters
loss_fct = "categorical_crossentropy"
metrics = ['accuracy']
local_epochs = 15

# %%
def train_local_model(model, node, x_train, y_train): 
    filepath = 'C:/Users/UX430/Documents/thesis/code/models/node'+str(node)+'id500.hdf5'
    callbacks = [
            keras.callbacks.EarlyStopping(
                monitor = 'val_loss', # Use accuracy to monitor the model
                patience = 10 # Stop after 10 steps with lower accuracy
            ),
            keras.callbacks.ModelCheckpoint(
                filepath = filepath, # file where the checkpoint is saved
                monitor = 'val_loss', # Don't overwrite the saved model unless val_loss is worse
                save_best_only = True)]# Only save model if it is the best
    optimizer = keras.optimizers.Adam(learning_rate=5e-4)
    model.compile(optimizer=optimizer, loss=loss_fct, metrics=metrics)
    history = model.fit(x_train, y_train, epochs=local_epochs, validation_split=0.2, callbacks=callbacks, batch_size=2048)
    return model, history.history['loss'], history.history['accuracy'], history.history['val_loss'], history.history['val_accuracy']

# %%
def aggregate(w_list): 
    avg_w = np.mean(w_list, axis=0)
    return avg_w

# %%
global_model = build_model((24,1,1))

# %%
x1, y1 = preprocessing(training1)
x2, y2 = preprocessing(training2)
x3, y3 = preprocessing(training3)
x4, y4 = preprocessing(training4)
x5, y5 = preprocessing(training5)
x6, y6 = preprocessing(training6)
x7, y7 = preprocessing(training7)

xbasic, ybasic = preprocessing(test_basic)
xplus, yplus = preprocessing(test_plus)

# %%
# Values saved each iteration 
loss_it = []
accuracy_it = []
f1_it = []
precision_it = []
recall_it = []

for i in range(global_updates): 
    w_list = []
    for node in range(num_nodes): 
        cp = global_model # create a copy of the global model
        if node == 0:
            x, y = x1, y1
        elif node == 1:
            x, y = x2, y2
        elif node == 2: 
            x, y = x3, y3
        elif node == 3: 
            x, y = x4, y4
        elif node == 4:
            x, y = x5, y5
        elif node == 5: 
            x, y = x6, y6
        else: 
            x, y = x7, y7
        local_model, local_loss, local_acc, local_val_loss, local_val_acc = train_local_model(cp, node, x, y)
        w_list.append(local_model.get_weights())

    avg_w = aggregate(w_list)
    global_model.set_weights(avg_w) # apply gradients to global model
    loss_basic, accuracy_basic, f1_basic, precision_basic, recall_basic = evaluation(global_model, xbasic, ybasic) # Evaluate with test basic to know progress
    loss_plus, accuracy_plus, f1_plus, precision_plus, recall_plus = evaluation(global_model, xplus, yplus) # Evaluate with test plus to know progress

    loss_it.append([loss_basic, loss_plus])
    accuracy_it.append([accuracy_basic, accuracy_plus])
    f1_it.append([f1_basic, f1_plus])
    precision_it.append([precision_basic, precision_plus])
    recall_it.append([recall_basic, recall_plus])


global_model.save('C:/Users/UX430/Documents/thesis/code/models/id500.hdf5')
# Out:
# Epoch 1/15
# 23/23 [==============================] - 25s 1s/step - loss: 1.5348 - accuracy: 0.6773 - val_loss: 2.6931 - val_accuracy: 0.0000e+00
# Epoch 2/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.2335 - accuracy: 0.9285 - val_loss: 4.5532 - val_accuracy: 0.5887
# Epoch 3/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0749 - accuracy: 0.9917 - val_loss: 5.1746 - val_accuracy: 0.5887
# Epoch 4/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0466 - accuracy: 0.9917 - val_loss: 5.1034 - val_accuracy: 0.5888
# Epoch 5/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0340 - accuracy: 0.9925 - val_loss: 5.1582 - val_accuracy: 0.5890
# Epoch 6/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0305 - accuracy: 0.9926 - val_loss: 5.2432 - val_accuracy: 0.5890
# Epoch 7/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0292 - accuracy: 0.9926 - val_loss: 5.2904 - val_accuracy: 0.5892
# Epoch 8/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0282 - accuracy: 0.9925 - val_loss: 5.3342 - val_accuracy: 0.5893
# Epoch 9/15
# 23/23 [==============================] - 34s 1s/step - loss: 0.0274 - accuracy: 0.9925 - val_loss: 5.3697 - val_accuracy: 0.5891
# Epoch 10/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0267 - accuracy: 0.9924 - val_loss: 5.3825 - val_accuracy: 0.5893
# Epoch 11/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0261 - accuracy: 0.9925 - val_loss: 5.3979 - val_accuracy: 0.5896
# Epoch 1/15
# 23/23 [==============================] - 32s 1s/step - loss: 0.0258 - accuracy: 0.9926 - val_loss: 5.8259 - val_accuracy: 0.5863
# Epoch 2/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0236 - accuracy: 0.9924 - val_loss: 6.1691 - val_accuracy: 0.5850
# Epoch 3/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0217 - accuracy: 0.9930 - val_loss: 6.5483 - val_accuracy: 0.5850
# Epoch 4/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0200 - accuracy: 0.9936 - val_loss: 6.9508 - val_accuracy: 0.5859
# Epoch 5/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0187 - accuracy: 0.9938 - val_loss: 7.2227 - val_accuracy: 0.5862
# Epoch 6/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 7.4712 - val_accuracy: 0.5884
# Epoch 7/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0167 - accuracy: 0.9944 - val_loss: 7.7748 - val_accuracy: 0.5885
# Epoch 8/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 7.9664 - val_accuracy: 0.5895
# Epoch 9/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 7.9752 - val_accuracy: 0.5912
# Epoch 10/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0159 - accuracy: 0.9951 - val_loss: 7.9770 - val_accuracy: 0.5915
# Epoch 11/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0154 - accuracy: 0.9951 - val_loss: 8.0651 - val_accuracy: 0.5913
# Epoch 1/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0192 - accuracy: 0.9944 - val_loss: 7.5227 - val_accuracy: 0.5945
# Epoch 2/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 7.6108 - val_accuracy: 0.5945
# Epoch 3/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0152 - accuracy: 0.9952 - val_loss: 7.7365 - val_accuracy: 0.5950
# Epoch 4/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 7.7548 - val_accuracy: 0.5949
# Epoch 5/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0145 - accuracy: 0.9956 - val_loss: 7.9802 - val_accuracy: 0.5938
# Epoch 6/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0145 - accuracy: 0.9956 - val_loss: 8.0965 - val_accuracy: 0.5950
# Epoch 7/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 8.0823 - val_accuracy: 0.5947
# Epoch 8/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 8.1317 - val_accuracy: 0.5941
# Epoch 9/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0143 - accuracy: 0.9959 - val_loss: 8.1929 - val_accuracy: 0.5951
# Epoch 10/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 8.0960 - val_accuracy: 0.5948
# Epoch 11/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 8.1337 - val_accuracy: 0.5944
# Epoch 1/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0221 - accuracy: 0.9938 - val_loss: 7.4774 - val_accuracy: 0.5918
# Epoch 2/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0155 - accuracy: 0.9952 - val_loss: 7.0239 - val_accuracy: 0.5914
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 7.1664 - val_accuracy: 0.5922
# Epoch 4/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 7.3014 - val_accuracy: 0.5920
# Epoch 5/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 7.3792 - val_accuracy: 0.5923
# Epoch 6/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0137 - accuracy: 0.9959 - val_loss: 7.6733 - val_accuracy: 0.5918
# Epoch 7/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 7.8003 - val_accuracy: 0.5939
# Epoch 8/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 7.7889 - val_accuracy: 0.5916
# Epoch 9/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 7.8034 - val_accuracy: 0.5937
# Epoch 10/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 7.9346 - val_accuracy: 0.5936
# Epoch 11/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 8.0493 - val_accuracy: 0.5932
# Epoch 12/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 8.1897 - val_accuracy: 0.5924
# Epoch 1/15
# 23/23 [==============================] - 36s 2s/step - loss: 0.0171 - accuracy: 0.9955 - val_loss: 7.8111 - val_accuracy: 0.5891
# Epoch 2/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 7.6998 - val_accuracy: 0.5889
# Epoch 3/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 7.6822 - val_accuracy: 0.5879
# Epoch 4/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 7.8473 - val_accuracy: 0.5885
# Epoch 5/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 7.9199 - val_accuracy: 0.5876
# Epoch 6/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 7.8374 - val_accuracy: 0.5880
# Epoch 7/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0134 - accuracy: 0.9963 - val_loss: 7.9466 - val_accuracy: 0.5887
# Epoch 8/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 7.9267 - val_accuracy: 0.5886
# Epoch 9/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 8.0105 - val_accuracy: 0.5880
# Epoch 10/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 8.0981 - val_accuracy: 0.5888
# Epoch 11/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 8.1843 - val_accuracy: 0.5888
# Epoch 12/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 8.1681 - val_accuracy: 0.5891
# Epoch 13/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0128 - accuracy: 0.9961 - val_loss: 8.1346 - val_accuracy: 0.5886
# Epoch 1/15
# 23/23 [==============================] - 37s 2s/step - loss: 0.0204 - accuracy: 0.9944 - val_loss: 7.4831 - val_accuracy: 0.5911
# Epoch 2/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 7.1737 - val_accuracy: 0.5909
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 7.3613 - val_accuracy: 0.5906
# Epoch 4/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 7.5367 - val_accuracy: 0.5906
# Epoch 5/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0100 - accuracy: 0.9972 - val_loss: 7.6351 - val_accuracy: 0.5900
# Epoch 6/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 7.7458 - val_accuracy: 0.5904
# Epoch 7/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 7.8426 - val_accuracy: 0.5908
# Epoch 8/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 7.9055 - val_accuracy: 0.5909
# Epoch 9/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 7.8828 - val_accuracy: 0.5903
# Epoch 10/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 7.9445 - val_accuracy: 0.5904
# Epoch 11/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 8.0821 - val_accuracy: 0.5904
# Epoch 12/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 8.0928 - val_accuracy: 0.5904
# Epoch 1/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0130 - accuracy: 0.9961 - val_loss: 7.7372 - val_accuracy: 0.5991
# Epoch 2/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 7.5351 - val_accuracy: 0.5986
# Epoch 3/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 7.5819 - val_accuracy: 0.5985
# Epoch 4/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 7.5983 - val_accuracy: 0.5986
# Epoch 5/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 7.7035 - val_accuracy: 0.6000
# Epoch 6/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 7.6557 - val_accuracy: 0.5998
# Epoch 7/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0116 - accuracy: 0.9965 - val_loss: 7.8657 - val_accuracy: 0.5987
# Epoch 8/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 7.9363 - val_accuracy: 0.5992
# Epoch 9/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 7.9912 - val_accuracy: 0.5995
# Epoch 10/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 8.1727 - val_accuracy: 0.5992
# Epoch 11/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0111 - accuracy: 0.9967 - val_loss: 8.4843 - val_accuracy: 0.5984
# Epoch 12/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 8.4817 - val_accuracy: 0.5987
# c:\Users\UX430\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# 4279/4279 [==============================] - 76s 18ms/step - loss: 1.5169 - accuracy: 0.9145
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 1721/1721 [==============================] - 38s 22ms/step - loss: 7.5092 - accuracy: 0.5531
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 7.4889 - val_accuracy: 0.5955
# Epoch 2/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 7.6732 - val_accuracy: 0.5953
# Epoch 3/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 7.8913 - val_accuracy: 0.5943
# Epoch 4/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0140 - accuracy: 0.9956 - val_loss: 7.9396 - val_accuracy: 0.5945
# Epoch 5/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0140 - accuracy: 0.9962 - val_loss: 7.7150 - val_accuracy: 0.5948
# Epoch 6/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 7.5400 - val_accuracy: 0.5943
# Epoch 7/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 7.5559 - val_accuracy: 0.5958
# Epoch 8/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 7.4995 - val_accuracy: 0.5943
# Epoch 9/15
# 23/23 [==============================] - 20s 888ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 7.9267 - val_accuracy: 0.5954
# Epoch 10/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0127 - accuracy: 0.9964 - val_loss: 8.0470 - val_accuracy: 0.5950
# Epoch 11/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 8.3465 - val_accuracy: 0.5953
# Epoch 1/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0137 - accuracy: 0.9962 - val_loss: 8.2574 - val_accuracy: 0.5906
# Epoch 2/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 8.2436 - val_accuracy: 0.5912
# Epoch 3/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0129 - accuracy: 0.9960 - val_loss: 8.2262 - val_accuracy: 0.5921
# Epoch 4/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0128 - accuracy: 0.9965 - val_loss: 8.2162 - val_accuracy: 0.5908
# Epoch 5/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 8.1213 - val_accuracy: 0.5912
# Epoch 6/15
# 23/23 [==============================] - 22s 973ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 8.3560 - val_accuracy: 0.5906
# Epoch 7/15
# 23/23 [==============================] - 23s 995ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 8.2848 - val_accuracy: 0.5919
# Epoch 8/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 8.3379 - val_accuracy: 0.5915
# Epoch 9/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 8.4188 - val_accuracy: 0.5904
# Epoch 10/15
# 23/23 [==============================] - 22s 942ms/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 8.3016 - val_accuracy: 0.5911
# Epoch 11/15
# 23/23 [==============================] - 22s 965ms/step - loss: 0.0106 - accuracy: 0.9971 - val_loss: 8.4493 - val_accuracy: 0.5913
# Epoch 12/15
# 23/23 [==============================] - 22s 966ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 8.6144 - val_accuracy: 0.5906
# Epoch 13/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 8.6577 - val_accuracy: 0.5905
# Epoch 14/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 8.6798 - val_accuracy: 0.5912
# Epoch 15/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 8.9347 - val_accuracy: 0.5904
# Epoch 1/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 8.9595 - val_accuracy: 0.5949
# Epoch 2/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 9.1592 - val_accuracy: 0.5956
# Epoch 3/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 9.0225 - val_accuracy: 0.5932
# Epoch 4/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 8.6372 - val_accuracy: 0.5944
# Epoch 5/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 8.5408 - val_accuracy: 0.5949
# Epoch 6/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 8.7300 - val_accuracy: 0.5953
# Epoch 7/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 8.8167 - val_accuracy: 0.5926
# Epoch 8/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 8.8381 - val_accuracy: 0.5952
# Epoch 9/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 8.8073 - val_accuracy: 0.5954
# Epoch 10/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 8.6358 - val_accuracy: 0.5942
# Epoch 11/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 8.7853 - val_accuracy: 0.5948
# Epoch 12/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 8.9668 - val_accuracy: 0.5947
# Epoch 13/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 8.9662 - val_accuracy: 0.5954
# Epoch 14/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 8.8750 - val_accuracy: 0.5946
# Epoch 15/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 8.9147 - val_accuracy: 0.5942
# Epoch 1/15
# 23/23 [==============================] - 33s 1s/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 8.8406 - val_accuracy: 0.5931
# Epoch 2/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 8.8629 - val_accuracy: 0.5931
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 9.0805 - val_accuracy: 0.5937
# Epoch 4/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 9.1935 - val_accuracy: 0.5931
# Epoch 5/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 9.2687 - val_accuracy: 0.5925
# Epoch 6/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 9.3859 - val_accuracy: 0.5929
# Epoch 7/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 9.4517 - val_accuracy: 0.5930
# Epoch 8/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 9.5005 - val_accuracy: 0.5936
# Epoch 9/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 9.5676 - val_accuracy: 0.5930
# Epoch 10/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 9.7380 - val_accuracy: 0.5932
# Epoch 11/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 9.8250 - val_accuracy: 0.5933
# Epoch 1/15
# 23/23 [==============================] - 33s 1s/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 9.6556 - val_accuracy: 0.5886
# Epoch 2/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0089 - accuracy: 0.9971 - val_loss: 9.6019 - val_accuracy: 0.5885
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 9.7248 - val_accuracy: 0.5877
# Epoch 4/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 9.7760 - val_accuracy: 0.5896
# Epoch 5/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 9.9360 - val_accuracy: 0.5890
# Epoch 6/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 9.7526 - val_accuracy: 0.5884
# Epoch 7/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 9.7742 - val_accuracy: 0.5896
# Epoch 8/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 9.9015 - val_accuracy: 0.5900
# Epoch 9/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 9.6692 - val_accuracy: 0.5889
# Epoch 10/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 9.9225 - val_accuracy: 0.5897
# Epoch 11/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 9.9509 - val_accuracy: 0.5902
# Epoch 12/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 9.8360 - val_accuracy: 0.5891
# Epoch 1/15
# 23/23 [==============================] - 32s 1s/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 9.4613 - val_accuracy: 0.5913
# Epoch 2/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 9.3532 - val_accuracy: 0.5921
# Epoch 3/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 9.1651 - val_accuracy: 0.5915
# Epoch 4/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 9.0493 - val_accuracy: 0.5909
# Epoch 5/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 9.1103 - val_accuracy: 0.5914
# Epoch 6/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 9.1627 - val_accuracy: 0.5917
# Epoch 7/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 9.0943 - val_accuracy: 0.5907
# Epoch 8/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 9.2155 - val_accuracy: 0.5913
# Epoch 9/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 8.9734 - val_accuracy: 0.5923
# Epoch 10/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 8.9948 - val_accuracy: 0.5910
# Epoch 11/15
# 23/23 [==============================] - 22s 976ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 8.9958 - val_accuracy: 0.5921
# Epoch 12/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 8.8926 - val_accuracy: 0.5919
# Epoch 13/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 8.8819 - val_accuracy: 0.5916
# Epoch 14/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 8.8683 - val_accuracy: 0.5910
# Epoch 15/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 8.9115 - val_accuracy: 0.5907
# Epoch 1/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 8.4650 - val_accuracy: 0.5995
# Epoch 2/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 8.2667 - val_accuracy: 0.5992
# Epoch 3/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 8.2005 - val_accuracy: 0.5998
# Epoch 4/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 8.2297 - val_accuracy: 0.5989
# Epoch 5/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 8.2223 - val_accuracy: 0.5994
# Epoch 6/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 8.4300 - val_accuracy: 0.5996
# Epoch 7/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 8.4725 - val_accuracy: 0.5997
# Epoch 8/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 8.5023 - val_accuracy: 0.5986
# Epoch 9/15
# 23/23 [==============================] - 22s 967ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 8.3773 - val_accuracy: 0.5998
# Epoch 10/15
# 23/23 [==============================] - 23s 980ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 8.4362 - val_accuracy: 0.5998
# Epoch 11/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 8.4426 - val_accuracy: 0.5996
# Epoch 12/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 8.5435 - val_accuracy: 0.5992
# Epoch 13/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 8.7771 - val_accuracy: 0.6001
# c:\Users\UX430\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# 4279/4279 [==============================] - 96s 22ms/step - loss: 1.7723 - accuracy: 0.9175
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 1721/1721 [==============================] - 33s 19ms/step - loss: 8.5508 - accuracy: 0.5577
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 9.0801 - val_accuracy: 0.5954
# Epoch 2/15
# 23/23 [==============================] - 23s 979ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 8.9787 - val_accuracy: 0.5958
# Epoch 3/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 9.1117 - val_accuracy: 0.5952
# Epoch 4/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0084 - accuracy: 0.9976 - val_loss: 9.2776 - val_accuracy: 0.5955
# Epoch 5/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0084 - accuracy: 0.9975 - val_loss: 9.4643 - val_accuracy: 0.5943
# Epoch 6/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 9.4533 - val_accuracy: 0.5935
# Epoch 7/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 9.5334 - val_accuracy: 0.5954
# Epoch 8/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 9.6012 - val_accuracy: 0.5954
# Epoch 9/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 9.7117 - val_accuracy: 0.5954
# Epoch 10/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 9.6727 - val_accuracy: 0.5949
# Epoch 11/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 9.7209 - val_accuracy: 0.5953
# Epoch 12/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 9.4388 - val_accuracy: 0.5954
# Epoch 1/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 9.4493 - val_accuracy: 0.5911
# Epoch 2/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 9.6196 - val_accuracy: 0.5913
# Epoch 3/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 9.2943 - val_accuracy: 0.5915
# Epoch 4/15
# 23/23 [==============================] - 22s 977ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 9.3698 - val_accuracy: 0.5918
# Epoch 5/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0088 - accuracy: 0.9973 - val_loss: 9.2481 - val_accuracy: 0.5901
# Epoch 6/15
# 23/23 [==============================] - 22s 968ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 9.2862 - val_accuracy: 0.5912
# Epoch 7/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 9.2038 - val_accuracy: 0.5912
# Epoch 8/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 9.0720 - val_accuracy: 0.5924
# Epoch 9/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 8.7635 - val_accuracy: 0.5907
# Epoch 10/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0081 - accuracy: 0.9978 - val_loss: 8.8610 - val_accuracy: 0.5906
# Epoch 11/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 8.8528 - val_accuracy: 0.5912
# Epoch 12/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 8.8764 - val_accuracy: 0.5906
# Epoch 13/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 8.9200 - val_accuracy: 0.5912
# Epoch 14/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 8.9393 - val_accuracy: 0.5914
# Epoch 15/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 8.9660 - val_accuracy: 0.5913
# Epoch 1/15
# 23/23 [==============================] - 33s 1s/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 9.0565 - val_accuracy: 0.5950
# Epoch 2/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 9.0473 - val_accuracy: 0.5946
# Epoch 3/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 9.0925 - val_accuracy: 0.5956
# Epoch 4/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 9.0507 - val_accuracy: 0.5953
# Epoch 5/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 9.0442 - val_accuracy: 0.5947
# Epoch 6/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 8.9721 - val_accuracy: 0.5950
# Epoch 7/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 8.9536 - val_accuracy: 0.5945
# Epoch 8/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 8.8958 - val_accuracy: 0.5949
# Epoch 9/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 8.8917 - val_accuracy: 0.5944
# Epoch 10/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 8.9295 - val_accuracy: 0.5950
# Epoch 11/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 8.9440 - val_accuracy: 0.5953
# Epoch 12/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 8.9035 - val_accuracy: 0.5950
# Epoch 13/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 8.5175 - val_accuracy: 0.5948
# Epoch 14/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 8.7059 - val_accuracy: 0.5955
# Epoch 15/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 8.5060 - val_accuracy: 0.5959
# Epoch 1/15
# 23/23 [==============================] - 33s 1s/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 8.1390 - val_accuracy: 0.5930
# Epoch 2/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 8.1628 - val_accuracy: 0.5937
# Epoch 3/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 8.1128 - val_accuracy: 0.5928
# Epoch 4/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 8.2249 - val_accuracy: 0.5940
# Epoch 5/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 8.2389 - val_accuracy: 0.5942
# Epoch 6/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 8.2232 - val_accuracy: 0.5936
# Epoch 7/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 8.3224 - val_accuracy: 0.5939
# Epoch 8/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 8.3811 - val_accuracy: 0.5936
# Epoch 9/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 8.4678 - val_accuracy: 0.5939
# Epoch 10/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 8.3783 - val_accuracy: 0.5939
# Epoch 11/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 8.5406 - val_accuracy: 0.5933
# Epoch 12/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 8.5696 - val_accuracy: 0.5937
# Epoch 13/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 8.4572 - val_accuracy: 0.5928
# Epoch 1/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0125 - accuracy: 0.9970 - val_loss: 9.0392 - val_accuracy: 0.5874
# Epoch 2/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 9.0195 - val_accuracy: 0.5893
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 8.8977 - val_accuracy: 0.5887
# Epoch 4/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 8.9242 - val_accuracy: 0.5891
# Epoch 5/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 8.9092 - val_accuracy: 0.5894
# Epoch 6/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 8.8958 - val_accuracy: 0.5889
# Epoch 7/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 8.9329 - val_accuracy: 0.5895
# Epoch 8/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 8.8502 - val_accuracy: 0.5890
# Epoch 9/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 8.9786 - val_accuracy: 0.5895
# Epoch 10/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 8.9188 - val_accuracy: 0.5891
# Epoch 11/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 8.8435 - val_accuracy: 0.5883
# Epoch 12/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 8.9915 - val_accuracy: 0.5895
# Epoch 13/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 8.9462 - val_accuracy: 0.5893
# Epoch 14/15
# 23/23 [==============================] - 23s 991ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 8.9655 - val_accuracy: 0.5877
# Epoch 15/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 8.9346 - val_accuracy: 0.5886
# Epoch 1/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 8.9820 - val_accuracy: 0.5918
# Epoch 2/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 8.7793 - val_accuracy: 0.5917
# Epoch 3/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 8.6992 - val_accuracy: 0.5915
# Epoch 4/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 8.7503 - val_accuracy: 0.5918
# Epoch 5/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 8.6032 - val_accuracy: 0.5915
# Epoch 6/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 8.5566 - val_accuracy: 0.5915
# Epoch 7/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 8.5066 - val_accuracy: 0.5915
# Epoch 8/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 8.5019 - val_accuracy: 0.5916
# Epoch 9/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 8.5551 - val_accuracy: 0.5919
# Epoch 10/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 8.5063 - val_accuracy: 0.5917
# Epoch 11/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 8.5142 - val_accuracy: 0.5905
# Epoch 12/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 8.4713 - val_accuracy: 0.5909
# Epoch 13/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 8.4970 - val_accuracy: 0.5915
# Epoch 14/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 8.5927 - val_accuracy: 0.5916
# Epoch 15/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 8.5849 - val_accuracy: 0.5914
# Epoch 1/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 8.2527 - val_accuracy: 0.5993
# Epoch 2/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 8.2247 - val_accuracy: 0.5994
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 8.2083 - val_accuracy: 0.5995
# Epoch 4/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 8.2528 - val_accuracy: 0.5992
# Epoch 5/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 8.3350 - val_accuracy: 0.5997
# Epoch 6/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 8.3556 - val_accuracy: 0.6001
# Epoch 7/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 8.2371 - val_accuracy: 0.5994
# Epoch 8/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 8.0830 - val_accuracy: 0.5987
# Epoch 9/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 8.3702 - val_accuracy: 0.5996
# Epoch 10/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 8.2611 - val_accuracy: 0.5992
# Epoch 11/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 8.3995 - val_accuracy: 0.5994
# Epoch 12/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 8.3506 - val_accuracy: 0.5999
# Epoch 13/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 8.3865 - val_accuracy: 0.5989
# Epoch 14/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 8.5008 - val_accuracy: 0.5992
# Epoch 15/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 8.5662 - val_accuracy: 0.5992
# c:\Users\UX430\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# 4279/4279 [==============================] - 89s 21ms/step - loss: 1.7039 - accuracy: 0.9186
# c:\Users\UX430\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 8.9953 - val_accuracy: 0.5912
# Epoch 4/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 9.0728 - val_accuracy: 0.5918
# Epoch 5/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 9.1082 - val_accuracy: 0.5912
# Epoch 6/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 9.0123 - val_accuracy: 0.5914
# Epoch 7/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 9.0804 - val_accuracy: 0.5912
# Epoch 8/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 8.8676 - val_accuracy: 0.5914
# Epoch 9/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 8.9042 - val_accuracy: 0.5915
# Epoch 10/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 8.8646 - val_accuracy: 0.5914
# Epoch 11/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 8.8152 - val_accuracy: 0.5907
# Epoch 12/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 8.9306 - val_accuracy: 0.5914
# Epoch 13/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 8.7266 - val_accuracy: 0.5907
# Epoch 14/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 8.7287 - val_accuracy: 0.5903
# Epoch 15/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 8.7696 - val_accuracy: 0.5914
# Epoch 1/15
# 23/23 [==============================] - 33s 1s/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 8.8037 - val_accuracy: 0.5960
# Epoch 2/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 8.7089 - val_accuracy: 0.5955
# Epoch 3/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 8.3338 - val_accuracy: 0.5945
# Epoch 4/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 8.5753 - val_accuracy: 0.5958
# Epoch 5/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 8.4901 - val_accuracy: 0.5956
# Epoch 6/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 8.6071 - val_accuracy: 0.5958
# Epoch 7/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 8.6811 - val_accuracy: 0.5959
# Epoch 8/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 8.8396 - val_accuracy: 0.5957
# Epoch 9/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 8.8905 - val_accuracy: 0.5961
# Epoch 10/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 8.6151 - val_accuracy: 0.5957
# Epoch 11/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 8.5812 - val_accuracy: 0.5956
# Epoch 12/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 8.6663 - val_accuracy: 0.5954
# Epoch 13/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 8.7037 - val_accuracy: 0.5953
# Epoch 1/15
# 23/23 [==============================] - 32s 1s/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 8.8695 - val_accuracy: 0.5937
# Epoch 2/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 8.5936 - val_accuracy: 0.5936
# Epoch 3/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 8.6369 - val_accuracy: 0.5939
# Epoch 4/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 8.5626 - val_accuracy: 0.5934
# Epoch 5/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 8.7699 - val_accuracy: 0.5937
# Epoch 6/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 8.6208 - val_accuracy: 0.5936
# Epoch 7/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 9.0675 - val_accuracy: 0.5946
# Epoch 8/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 8.7613 - val_accuracy: 0.5935
# Epoch 9/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 8.9845 - val_accuracy: 0.5940
# Epoch 10/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 8.8902 - val_accuracy: 0.5935
# Epoch 11/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 9.0862 - val_accuracy: 0.5937
# Epoch 12/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 9.0762 - val_accuracy: 0.5936
# Epoch 13/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 9.1390 - val_accuracy: 0.5937
# Epoch 14/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 9.3360 - val_accuracy: 0.5938
# Epoch 1/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 9.3071 - val_accuracy: 0.5902
# Epoch 2/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 8.8170 - val_accuracy: 0.5890
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 8.9950 - val_accuracy: 0.5891
# Epoch 4/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 9.1093 - val_accuracy: 0.5894
# Epoch 5/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 9.0629 - val_accuracy: 0.5893
# Epoch 6/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 9.2263 - val_accuracy: 0.5901
# Epoch 7/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 9.1744 - val_accuracy: 0.5891
# Epoch 8/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 9.2803 - val_accuracy: 0.5899
# Epoch 9/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 9.3046 - val_accuracy: 0.5895
# Epoch 10/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 9.5014 - val_accuracy: 0.5900
# Epoch 11/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 9.3744 - val_accuracy: 0.5891
# Epoch 12/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 9.5623 - val_accuracy: 0.5896
# Epoch 1/15
# 23/23 [==============================] - 36s 2s/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 9.7571 - val_accuracy: 0.5920
# Epoch 2/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 9.7228 - val_accuracy: 0.5917
# Epoch 3/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 9.5001 - val_accuracy: 0.5917
# Epoch 4/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 9.4793 - val_accuracy: 0.5918
# Epoch 5/15
# 23/23 [==============================] - 29s 1s/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 9.3920 - val_accuracy: 0.5915
# Epoch 6/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 9.4044 - val_accuracy: 0.5916
# Epoch 7/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 9.5397 - val_accuracy: 0.5918
# Epoch 8/15
# 23/23 [==============================] - 22s 974ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 9.6699 - val_accuracy: 0.5920
# Epoch 9/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 9.3649 - val_accuracy: 0.5916
# Epoch 10/15
# 23/23 [==============================] - 23s 1s/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 9.3393 - val_accuracy: 0.5915
# Epoch 11/15
# 23/23 [==============================] - 23s 982ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 9.5396 - val_accuracy: 0.5916
# Epoch 12/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 9.4043 - val_accuracy: 0.5915
# Epoch 13/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 9.4965 - val_accuracy: 0.5915
# Epoch 14/15
# 23/23 [==============================] - 23s 989ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 9.5989 - val_accuracy: 0.5917
# Epoch 15/15
# 23/23 [==============================] - 24s 1s/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 9.6285 - val_accuracy: 0.5916
# Epoch 1/15
# 23/23 [==============================] - 31s 1s/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 8.8449 - val_accuracy: 0.5988
# Epoch 2/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 9.1032 - val_accuracy: 0.5997
# Epoch 3/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 8.9327 - val_accuracy: 0.5991
# Epoch 4/15
# 23/23 [==============================] - 30s 1s/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 8.9374 - val_accuracy: 0.5995
# Epoch 5/15
# 23/23 [==============================] - 27s 1s/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 9.2411 - val_accuracy: 0.5998
# Epoch 6/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 9.1490 - val_accuracy: 0.5997
# Epoch 7/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 8.9825 - val_accuracy: 0.5989
# Epoch 8/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 9.1580 - val_accuracy: 0.5998
# Epoch 9/15
# 23/23 [==============================] - 25s 1s/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 9.2625 - val_accuracy: 0.5998
# Epoch 10/15
# 23/23 [==============================] - 26s 1s/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 9.3638 - val_accuracy: 0.5997
# Epoch 11/15
# 23/23 [==============================] - 28s 1s/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 9.4559 - val_accuracy: 0.5998
# c:\Users\UX430\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# 4279/4279 [==============================] - 86s 20ms/step - loss: 1.8236 - accuracy: 0.9187
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15040/967483433.py in <module>
#      29     avg_w = aggregate(w_list)
#      30     global_model.set_weights(avg_w) # apply gradients to global model
# ---> 31     loss_basic, accuracy_basic, f1_basic, precision_basic, recall_basic = evaluation(global_model, xbasic, ybasic) # Evaluate with test basic to know progress
#      32     loss_plus, accuracy_plus, f1_plus, precision_plus, recall_plus = evaluation(global_model, xplus, yplus) # Evaluate with test plus to know progress
#      33
#
# ~\AppData\Local\Temp/ipykernel_15040/3151749806.py in evaluation(model, x, y)
#       2 def evaluation(model, x, y):
#       3     loss, accuracy = model.evaluate(x, y)
# ----> 4     y_pred = model.predict(x)
#       5     y_pred = np.argmax(y_pred, axis=1)
#       6     y = np.argmax(y, axis=1)
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     123       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     124           method.__name__))
# --> 125     return method(self, *args, **kwargs)
#     126
#     127   return tf_decorator.make_decorator(
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1592           for step in data_handler.steps():
#    1593             callbacks.on_predict_batch_begin(step)
# -> 1594             tmp_batch_outputs = predict_function(iterator)
#    1595             if data_handler.should_sync:
#    1596               context.async_wait()
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# c:\Users\UX430\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print("Loss for iterations: ", loss_it)
print("Accuracy for iterations: ", accuracy_it)
print("F1 for iterations: ", f1_it)
print("Precision for iterations: ", precision_it)
print("Recall for iterations: ", recall_it)
# Out:
# Loss for Test Basic:  1.976881980895996  Loss for Test Plus:  9.3706693649292
# Accuracy for Test Basic:  0.9105290770530701  Accuracy for Test Plus:  0.548263430595398
# F1 for Test Basic:  0.8740143706811211  F1 for Test Plus:  0.5187715709466334
# Precision for Test Basic:  0.8423697279453707  Precision for Test Plus:  0.4922905463396894
# Recall for Test Basic:  0.9105290835256654  Recall for Test Plus:  0.5482634600014532

# %% [markdown]
# #### Dataset 7B

# %%
# Load training datasets and testing datasets 
training1 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7B-Part1.csv')
training2 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7B-Part2.csv')
training3 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7B-Part3.csv')
training4 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7B-Part4.csv')
training5 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7B-Part5.csv')
training6 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7B-Part6.csv')
training7 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7B-Part7.csv')
test_basic = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test-Basic.csv')
test_plus = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test+.csv')

# %%
# Define 
node_datasets = [training1, training2, training3, training4, training5, training6, training7]
num_nodes = 7
global_updates = 10

# Define model training parameters
loss_fct = "categorical_crossentropy"
metrics = ['accuracy']
local_epochs = 15

# %%
def train_local_model(model, node, x_train, y_train): 
    filepath = 'C:/Users/UX430/Documents/thesis/code/models/node'+str(node)+'id501.hdf5'
    callbacks = [
            keras.callbacks.EarlyStopping(
                monitor = 'val_loss', # Use accuracy to monitor the model
                patience = 10 # Stop after 10 steps with lower accuracy
            ),
            keras.callbacks.ModelCheckpoint(
                filepath = filepath, # file where the checkpoint is saved
                monitor = 'val_loss', # Don't overwrite the saved model unless val_loss is worse
                save_best_only = True)]# Only save model if it is the best
    optimizer = keras.optimizers.Adam(learning_rate=5e-4)
    model.compile(optimizer=optimizer, loss=loss_fct, metrics=metrics)
    history = model.fit(x_train, y_train, epochs=local_epochs, validation_split=0.2, callbacks=callbacks, batch_size=2048)
    return model, history.history['loss'], history.history['accuracy'], history.history['val_loss'], history.history['val_accuracy']

# %%
def aggregate(w_list): 
    avg_w = np.mean(w_list, axis=0)
    return avg_w

# %%
global_model = build_model((24,1,1))

# %%
x1, y1 = preprocessing(training1)
x2, y2 = preprocessing(training2)
x3, y3 = preprocessing(training3)
x4, y4 = preprocessing(training4)
x5, y5 = preprocessing(training5)
x6, y6 = preprocessing(training6)
x7, y7 = preprocessing(training7)

xbasic, ybasic = preprocessing(test_basic)
xplus, yplus = preprocessing(test_plus)

# %%
# Values saved each iteration 
loss_it = []
accuracy_it = []
f1_it = []
precision_it = []
recall_it = []

for i in range(global_updates): 
    w_list = []
    for node in range(num_nodes): 
        cp = global_model # create a copy of the global model
        if node == 0:
            x, y = x1, y1
        elif node == 1:
            x, y = x2, y2
        elif node == 2: 
            x, y = x3, y3
        elif node == 3: 
            x, y = x4, y4
        elif node == 4:
            x, y = x5, y5
        elif node == 5: 
            x, y = x6, y6
        else: 
            x, y = x7, y7
        local_model, local_loss, local_acc, local_val_loss, local_val_acc = train_local_model(cp, node, x, y)
        w_list.append(local_model.get_weights())

    avg_w = aggregate(w_list)
    global_model.set_weights(avg_w) # apply gradients to global model
    loss_basic, accuracy_basic, f1_basic, precision_basic, recall_basic = evaluation(global_model, xbasic, ybasic) # Evaluate with test basic to know progress
    loss_plus, accuracy_plus, f1_plus, precision_plus, recall_plus = evaluation(global_model, xplus, yplus) # Evaluate with test plus to know progress

    loss_it.append([loss_basic, loss_plus])
    accuracy_it.append([accuracy_basic, accuracy_plus])
    f1_it.append([f1_basic, f1_plus])
    precision_it.append([precision_basic, precision_plus])
    recall_it.append([recall_basic, recall_plus])


global_model.save('C:/Users/UX430/Documents/thesis/code/models/id501.hdf5')

# %%
print("Loss for iterations: ", loss_it)
print("Accuracy for iterations: ", accuracy_it)
print("F1 for iterations: ", f1_it)
print("Precision for iterations: ", precision_it)
print("Recall for iterations: ", recall_it)

# %% [markdown]
# #### Dataset 7C

# %%
# Load training datasets and testing datasets 
training1 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7C-Part1.csv')
training2 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7C-Part2.csv')
training3 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7C-Part3.csv')
training4 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7C-Part4.csv')
training5 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7C-Part5.csv')
training6 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7C-Part6.csv')
training7 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7C-Part7.csv')
test_basic = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test-Basic.csv')
test_plus = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test+.csv')

# %%
# Define 
node_datasets = [training1, training2, training3, training4, training5, training6, training7]
num_nodes = 7
global_updates = 10

# Define model training parameters
loss_fct = "categorical_crossentropy"
metrics = ['accuracy']
local_epochs = 15

# %%
def train_local_model(model, node, x_train, y_train): 
    filepath = 'C:/Users/UX430/Documents/thesis/code/models/node'+str(node)+'id502.hdf5'
    callbacks = [
            keras.callbacks.EarlyStopping(
                monitor = 'val_loss', # Use accuracy to monitor the model
                patience = 10 # Stop after 10 steps with lower accuracy
            ),
            keras.callbacks.ModelCheckpoint(
                filepath = filepath, # file where the checkpoint is saved
                monitor = 'val_loss', # Don't overwrite the saved model unless val_loss is worse
                save_best_only = True)]# Only save model if it is the best
    optimizer = keras.optimizers.Adam(learning_rate=5e-4)
    model.compile(optimizer=optimizer, loss=loss_fct, metrics=metrics)
    history = model.fit(x_train, y_train, epochs=local_epochs, validation_split=0.2, callbacks=callbacks, batch_size=2048)
    return model, history.history['loss'], history.history['accuracy'], history.history['val_loss'], history.history['val_accuracy']

# %%
def aggregate(w_list): 
    avg_w = np.mean(w_list, axis=0)
    return avg_w

# %%
global_model = build_model((24,1,1))

# %%
x1, y1 = preprocessing(training1)
x2, y2 = preprocessing(training2)
x3, y3 = preprocessing(training3)
x4, y4 = preprocessing(training4)
x5, y5 = preprocessing(training5)
x6, y6 = preprocessing(training6)
x7, y7 = preprocessing(training7)

xbasic, ybasic = preprocessing(test_basic)
xplus, yplus = preprocessing(test_plus)

# %%
# Values saved each iteration 
loss_it = []
accuracy_it = []
f1_it = []
precision_it = []
recall_it = []

for i in range(global_updates): 
    w_list = []
    for node in range(num_nodes): 
        cp = global_model # create a copy of the global model
        if node == 0:
            x, y = x1, y1
        elif node == 1:
            x, y = x2, y2
        elif node == 2: 
            x, y = x3, y3
        elif node == 3: 
            x, y = x4, y4
        elif node == 4:
            x, y = x5, y5
        elif node == 5: 
            x, y = x6, y6
        else: 
            x, y = x7, y7
        local_model, local_loss, local_acc, local_val_loss, local_val_acc = train_local_model(cp, node, x, y)
        w_list.append(local_model.get_weights())

    avg_w = aggregate(w_list)
    global_model.set_weights(avg_w) # apply gradients to global model
    loss_basic, accuracy_basic, f1_basic, precision_basic, recall_basic = evaluation(global_model, xbasic, ybasic) # Evaluate with test basic to know progress
    loss_plus, accuracy_plus, f1_plus, precision_plus, recall_plus = evaluation(global_model, xplus, yplus) # Evaluate with test plus to know progress

    loss_it.append([loss_basic, loss_plus])
    accuracy_it.append([accuracy_basic, accuracy_plus])
    f1_it.append([f1_basic, f1_plus])
    precision_it.append([precision_basic, precision_plus])
    recall_it.append([recall_basic, recall_plus])


global_model.save('C:/Users/UX430/Documents/thesis/code/models/id502.hdf5')

# %%
print("Loss for iterations: ", loss_it)
print("Accuracy for iterations: ", accuracy_it)
print("F1 for iterations: ", f1_it)
print("Precision for iterations: ", precision_it)
print("Recall for iterations: ", recall_it)

# %% [markdown]
# ### Experimenting with epochs and iterations
#
# Use of dataset 7A, considering it contains an equal partition of the data between the 7 nodes.

# %% [markdown]
# #### #Epochs = 10, #Iterations = 10

# %%
# Load training datasets and testing datasets 
training1 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part1.csv')
training2 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part2.csv')
training3 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part3.csv')
training4 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part4.csv')
training5 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part5.csv')
training6 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part6.csv')
training7 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part7.csv')
test_basic = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test-Basic.csv')
test_plus = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test+.csv')

# %%
# Define 
node_datasets = [training1, training2, training3, training4, training5, training6, training7]
num_nodes = 7
global_updates = 10

# Define model training parameters
loss_fct = "categorical_crossentropy"
metrics = ['accuracy']
local_epochs = 10

# %%
def train_local_model(model, node, x_train, y_train): 
    filepath = 'C:/Users/UX430/Documents/thesis/code/models/node'+str(node)+'id510.hdf5'
    callbacks = [
            keras.callbacks.EarlyStopping(
                monitor = 'val_loss', # Use accuracy to monitor the model
                patience = 10 # Stop after 10 steps with lower accuracy
            ),
            keras.callbacks.ModelCheckpoint(
                filepath = filepath, # file where the checkpoint is saved
                monitor = 'val_loss', # Don't overwrite the saved model unless val_loss is worse
                save_best_only = True)]# Only save model if it is the best
    optimizer = keras.optimizers.Adam(learning_rate=5e-4)
    model.compile(optimizer=optimizer, loss=loss_fct, metrics=metrics)
    history = model.fit(x_train, y_train, epochs=local_epochs, validation_split=0.2, callbacks=callbacks, batch_size=2048)
    return model, history.history['loss'], history.history['accuracy'], history.history['val_loss'], history.history['val_accuracy']

# %%
def aggregate(w_list): 
    avg_w = np.mean(w_list, axis=0)
    return avg_w

# %%
global_model = build_model((24,1,1))

# %%
x1, y1 = preprocessing(training1)
x2, y2 = preprocessing(training2)
x3, y3 = preprocessing(training3)
x4, y4 = preprocessing(training4)
x5, y5 = preprocessing(training5)
x6, y6 = preprocessing(training6)
x7, y7 = preprocessing(training7)

xbasic, ybasic = preprocessing(test_basic)
xplus, yplus = preprocessing(test_plus)

# %%
# Values saved each iteration 
loss_it = []
accuracy_it = []
f1_it = []
precision_it = []
recall_it = []

for i in range(global_updates): 
    w_list = []
    for node in range(num_nodes): 
        cp = global_model # create a copy of the global model
        if node == 0:
            x, y = x1, y1
        elif node == 1:
            x, y = x2, y2
        elif node == 2: 
            x, y = x3, y3
        elif node == 3: 
            x, y = x4, y4
        elif node == 4:
            x, y = x5, y5
        elif node == 5: 
            x, y = x6, y6
        else: 
            x, y = x7, y7
        local_model, local_loss, local_acc, local_val_loss, local_val_acc = train_local_model(cp, node, x, y)
        w_list.append(local_model.get_weights())

    avg_w = aggregate(w_list)
    global_model.set_weights(avg_w) # apply gradients to global model
    loss_basic, accuracy_basic, f1_basic, precision_basic, recall_basic = evaluation(global_model, xbasic, ybasic) # Evaluate with test basic to know progress
    loss_plus, accuracy_plus, f1_plus, precision_plus, recall_plus = evaluation(global_model, xplus, yplus) # Evaluate with test plus to know progress

    loss_it.append([loss_basic, loss_plus])
    accuracy_it.append([accuracy_basic, accuracy_plus])
    f1_it.append([f1_basic, f1_plus])
    precision_it.append([precision_basic, precision_plus])
    recall_it.append([recall_basic, recall_plus])


global_model.save('C:/Users/UX430/Documents/thesis/code/models/id510.hdf5')

# %%
print("Loss for iterations: ", loss_it)
print("Accuracy for iterations: ", accuracy_it)
print("F1 for iterations: ", f1_it)
print("Precision for iterations: ", precision_it)
print("Recall for iterations: ", recall_it)

# %% [markdown]
# #### #Epochs = 5, #Iterations = 5

# %%
# Load training datasets and testing datasets 
training1 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part1.csv')
training2 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part2.csv')
training3 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part3.csv')
training4 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part4.csv')
training5 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part5.csv')
training6 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part6.csv')
training7 = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Train-Basic-7A-Part7.csv')
test_basic = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test-Basic.csv')
test_plus = pd.read_csv('C:/Users/UX430/Documents/thesis/datasets/UNSW-NB15/UNSW-NB15-Test+.csv')

# %%
# Define 
node_datasets = [training1, training2, training3, training4, training5, training6, training7]
num_nodes = 7
global_updates = 5

# Define model training parameters
loss_fct = "categorical_crossentropy"
metrics = ['accuracy']
local_epochs = 5

# %%
def train_local_model(model, node, x_train, y_train): 
    filepath = 'C:/Users/UX430/Documents/thesis/code/models/node'+str(node)+'id511.hdf5'
    callbacks = [
            keras.callbacks.EarlyStopping(
                monitor = 'val_loss', # Use accuracy to monitor the model
                patience = 10 # Stop after 10 steps with lower accuracy
            ),
            keras.callbacks.ModelCheckpoint(
                filepath = filepath, # file where the checkpoint is saved
                monitor = 'val_loss', # Don't overwrite the saved model unless val_loss is worse
                save_best_only = True)]# Only save model if it is the best
    optimizer = keras.optimizers.Adam(learning_rate=5e-4)
    model.compile(optimizer=optimizer, loss=loss_fct, metrics=metrics)
    history = model.fit(x_train, y_train, epochs=local_epochs, validation_split=0.2, callbacks=callbacks, batch_size=2048)
    return model, history.history['loss'], history.history['accuracy'], history.history['val_loss'], history.history['val_accuracy']

# %%
def aggregate(w_list): 
    avg_w = np.mean(w_list, axis=0)
    return avg_w

# %%
global_model = build_model((24,1,1))

# %%
x1, y1 = preprocessing(training1)
x2, y2 = preprocessing(training2)
x3, y3 = preprocessing(training3)
x4, y4 = preprocessing(training4)
x5, y5 = preprocessing(training5)
x6, y6 = preprocessing(training6)
x7, y7 = preprocessing(training7)

xbasic, ybasic = preprocessing(test_basic)
xplus, yplus = preprocessing(test_plus)

# %%
# Values saved each iteration 
loss_it = []
accuracy_it = []
f1_it = []
precision_it = []
recall_it = []

for i in range(global_updates): 
    w_list = []
    for node in range(num_nodes): 
        cp = global_model # create a copy of the global model
        if node == 0:
            x, y = x1, y1
        elif node == 1:
            x, y = x2, y2
        elif node == 2: 
            x, y = x3, y3
        elif node == 3: 
            x, y = x4, y4
        elif node == 4:
            x, y = x5, y5
        elif node == 5: 
            x, y = x6, y6
        else: 
            x, y = x7, y7
        local_model, local_loss, local_acc, local_val_loss, local_val_acc = train_local_model(cp, node, x, y)
        w_list.append(local_model.get_weights())

    avg_w = aggregate(w_list)
    global_model.set_weights(avg_w) # apply gradients to global model
    loss_basic, accuracy_basic, f1_basic, precision_basic, recall_basic = evaluation(global_model, xbasic, ybasic) # Evaluate with test basic to know progress
    loss_plus, accuracy_plus, f1_plus, precision_plus, recall_plus = evaluation(global_model, xplus, yplus) # Evaluate with test plus to know progress

    loss_it.append([loss_basic, loss_plus])
    accuracy_it.append([accuracy_basic, accuracy_plus])
    f1_it.append([f1_basic, f1_plus])
    precision_it.append([precision_basic, precision_plus])
    recall_it.append([recall_basic, recall_plus])


global_model.save('C:/Users/UX430/Documents/thesis/code/models/id511.hdf5')

# %%
print("Loss for iterations: ", loss_it)
print("Accuracy for iterations: ", accuracy_it)
print("F1 for iterations: ", f1_it)
print("Precision for iterations: ", precision_it)
print("Recall for iterations: ", recall_it)
